# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
import time

# Variables para DataFrame
tags_urgents = []
tags_featured = []
jobs_title = []
companies_name = []
companies_link = []
companies_calcifications = []
companies_locations = []
companies_locations_after = []
short_descriptions = []
how_longs = []

# Captura del tema de interés de la persona
interest = input("¿Cuál es el trabajo de tu interés?: ")
print('\n')

# Acceso a la página
driver =  webdriver.Chrome(service = Service(ChromeDriverManager().install()))
driver.get("https://co.computrabajo.com/")
search_bar = driver.find_element(By.CSS_SELECTOR, "input#prof-cat-search-input")
search_bar.clear()
search_bar.send_keys(interest)
search_bar.send_keys(Keys.RETURN)

# Título del trabajo
title_jobs = driver.find_elements(By.XPATH, "//a[@class='js-o-link fc_base']")

# Div (Urgente - Destacado) (contiene varios elementos)
elements = driver.find_elements(By.CSS_SELECTOR, "div.w100.bClick")


# Ciclo para separa cada uno de los elementos
for element in elements:
# ****************************************************************************************************************
    # Captura de la etiqueta "urgente" en las ofertas que la tengan
    spans_u =  element.find_elements(By.CSS_SELECTOR, 'span.tag.urgent.mr10.mb10')
    if spans_u: 
        for span_u in spans_u:
            tags_urgents.append(span_u.text)
    else: tags_urgents.append('...')

# ****************************************************************************************************************
        
    # Captura de la etiqueta "destacado" en las ofertas que la tengan
    spans_d =  element.find_elements(By.CSS_SELECTOR, 'span.tag.dest.mr10.mb10')
    if spans_d: 
        for span_d in spans_d:
            tags_featured.append(span_d.text)
    else: tags_featured.append('...')
    
# ****************************************************************************************************************

    # Captura del título de la oferta
    jobs = element.find_elements(By.CSS_SELECTOR, 'a.js-o-link.fc_base')
    if jobs:
        for job in jobs:
            jobs_title.append(job.text)
    else: jobs_title.append("...")
    
# ****************************************************************************************************************

    # Captura del nombre de la empresa que oferta el trabajo
    companies = element.find_elements(By.CSS_SELECTOR, 'a.fc_base.hover.it-blank')
    if companies:
        for company in companies:
            companies_name.append(company.text)
    else: companies_name.append("...")
        
# ****************************************************************************************************************

    # Captura del enlace a la página de la empresa
    companies = element.find_elements(By.CSS_SELECTOR, 'a.fc_base.hover.it-blank')
    if companies:
        for company in companies:
            companies_link.append(company.get_attribute('href'))
    else: companies_link.append("...")
        
# ****************************************************************************************************************
    
    # Captura de la calificación de la empresa
    ratings = element.find_elements(By.CSS_SELECTOR, 'span.ml10.mr10')
    if ratings:
        for rating in ratings:
            companies_calcifications.append(rating.text)
    else: companies_calcifications.append("...")
                
# ****************************************************************************************************************
    
    # Captura de la ubicación de la empresa
    locations = element.find_elements(By.CSS_SELECTOR, 'p.fs16.fc_base.mt5.mb10')
    if locations:
        for location in locations:
            companies_locations.append(location.get_attribute('textContent'))
    else: companies_locations.append("...")
        
# ****************************************************************************************************************
            
    # Captura de la descripción oferta del trabajo
    descriptions = element.find_elements(By.CSS_SELECTOR, "p.fc_aux.t_word_wrap.mb10.hide_m")
    
    if descriptions:
        for description in descriptions:
            short_descriptions.append(description.text)
    else: short_descriptions.append("...")
        
# ****************************************************************************************************************

    # Captura de la hora de publicación de la oferta
    longs = element.find_elements(By.CSS_SELECTOR, "p.fs13.fc_aux")
    
    if longs:
        for long in longs:
            how_longs.append(long.text)
    else: how_longs.append("...")
        
# ****************************************************************************************************************
                
companies_locations_after = [company_location.split('\n')[-1].strip(' ') for company_location in companies_locations]

data_jobs = {
    "tags_urgents": tags_urgents,
    "tags_featured": tags_featured,
    "jobs_title": jobs_title,
    "companies_name": companies_name,
    "companies_link": companies_link,
    "companies_calcifications": companies_calcifications,
    "companies_locations_after": companies_locations_after,
    "short_descriptions": short_descriptions,
    "how_longs": how_longs
}

df =  pd.DataFrame(data_jobs)
driver.close()
# Out:
# ¿Cuál es el trabajo de tu interés?: Laravel

# %%
df
# Out:
#           tags_urgents     tags_featured  \
# 0                  ...               ...
# 1                  ...  Empleo destacado
# 2                  ...               ...
# 3                  ...               ...
# 4                  ...               ...
# 5   Se precisa Urgente               ...
# 6   Se precisa Urgente  Empleo destacado
# 7   Se precisa Urgente  Empleo destacado
# 8   Se precisa Urgente  Empleo destacado
# 9                  ...               ...
# 10                 ...               ...
# 11                 ...               ...
# 12  Se precisa Urgente  Empleo destacado
# 13                 ...               ...
# 14                 ...               ...
# 15  Se precisa Urgente  Empleo destacado
# 16  Se precisa Urgente  Empleo destacado
# 17                 ...               ...
# 18  Se precisa Urgente  Empleo destacado
# 19  Se precisa Urgente               ...
#
#                                            jobs_title  \
# 0                     Programador PHP Laravel Linux :
# 1                         Desarrollador/a PHP Laravel
# 2     Desarrollador Full Stack Angular, PHP y Laravel
# 3                      Arquitecto de Software Laravel
# 4                      Arquitecto de Software Laravel
# 5                      Arquitecto de Software Laravel
# 6                               Desarrollador Laravel
# 7                            Desarrollador PHP Middle
# 8                            Desarrollador PHP Middle
# 9                           Desarrollador de Software
# 10                       Desarrollador de PHP Laravel
# 11                   Desarrollador junior PHP Laravel
# 12                        Desarrollador Php y Laravel
# 13  programador/a Senior conocimientos en Laravel,...
# 14                             Programador PHP Junior
# 15                           Desarrollador Full stack
# 16                    Líder en Desarrollo de Software
# 17                              Ingeniero de sistemas
# 18                                  Desarrollador PHP
# 19                               analista programador
#
#                                       companies_name  \
# 0                               MetaBiblioteca S.A.S
# 1                                       wOutsourcing
# 2                                          Grupo OET
# 3                                            KONECTA
# 4                                            KONECTA
# 5                                            KONECTA
# 6                             Closer Design Networks
# 7                                    MISION TEMPORAL
# 8                                    MISION TEMPORAL
# 9                   Agencia de empleo de Colsubsidio
# 10                                      2B eCommerce
# 11                                      TEMPO S.A.S.
# 12                                               ...
# 13                                  Radio Enlace SAS
# 14                           SAVIA SERVICIOS SAS ESP
# 15                                     GRUPO ALIANZA
# 16                                               ...
# 17  ORGANIZACION CLINICA BONNADONA - PREVENIR S.A.S.
# 18                          BROWSER TRAVEL SOLUTIONS
# 19                                    Espumados S.A.
#
#                                        companies_link  \
# 0   https://co.computrabajo.com/empresas/ofertas-d...
# 1   https://co.computrabajo.com/empresas/ofertas-d...
# 2   https://co.computrabajo.com/empresas/ofertas-d...
# 3                 https://co.computrabajo.com/konecta
# 4                 https://co.computrabajo.com/konecta
# 5                 https://co.computrabajo.com/konecta
# 6   https://co.computrabajo.com/empresas/ofertas-d...
# 7   https://co.computrabajo.com/empresas/ofertas-d...
# 8   https://co.computrabajo.com/empresas/ofertas-d...
# 9   https://co.computrabajo.com/caja-colombiana-de...
# 10  https://co.computrabajo.com/empresas/ofertas-d...
# 11  https://co.computrabajo.com/empresas/ofertas-d...
# 12                                                ...
# 13  https://co.computrabajo.com/empresas/ofertas-d...
# 14  https://co.computrabajo.com/empresas/ofertas-d...
# 15           https://co.computrabajo.com/grupoalianza
# 16                                                ...
# 17  https://co.computrabajo.com/empresas/ofertas-d...
# 18  https://co.computrabajo.com/empresas/ofertas-d...
# 19  https://co.computrabajo.com/empresas/ofertas-d...
#
#    companies_calcifications   companies_locations_after  \
# 0                       ...  Bogotá, D.C., Bogotá, D.C.
# 1                       4,0  Bogotá, D.C., Bogotá, D.C.
# 2                       4,2  Bogotá, D.C., Bogotá, D.C.
# 3                       4,2  Bogotá, D.C., Bogotá, D.C.
# 4                       4,2           Córdoba, Montería
# 5                       4,2  Bogotá, D.C., Bogotá, D.C.
# 6                       ...  Bogotá, D.C., Bogotá, D.C.
# 7                       4,3               Nariño, Pasto
# 8                       4,3         Antioquia, Medellín
# 9                       ...  Bogotá, D.C., Bogotá, D.C.
# 10                      ...         Antioquia, Medellín
# 11                      4,3     Atlántico, Barranquilla
# 12                      ...            Santander, Girón
# 13                      ...         Antioquia, Medellín
# 14                      ...         Antioquia, Medellín
# 15                      4,0  Bogotá, D.C., Bogotá, D.C.
# 16                      ...  Bogotá, D.C., Bogotá, D.C.
# 17                      4,2     Atlántico, Barranquilla
# 18                      3,7  Bogotá, D.C., Bogotá, D.C.
# 19                      4,3        Cundinamarca, Soacha
#
#                                    short_descriptions        how_longs
# 0   Importante empresa del sector de Servicios Edu...    Hace 20 horas
# 1   Somos una compañía con más de 28 años de exper...      Hace 2 días
# 2   Empresa que ofrece servicios de Soluciones Dig...      Hace 2 días
# 3   Haz parte de nuestro equipo y vive experiencia...      Hace 2 días
# 4   Haz parte de nuestro equipo y vive experiencia...      Hace 3 días
# 5   Haz parte de nuestro equipo y vive experiencia...      Hace 3 días
# 6   Trabaja en el desarrollo de productos innovado...      Hace 3 días
# 7   Importante compañia solicita para su equipo de...      Hace 5 días
# 8   Importante compañia solicita para su equipo de...      Hace 5 días
# 9   Importante empresa requiere de manera urgente ...      Hace 5 días
# 10  El desarrollador de PHP es responsable de desa...      Hace 5 días
# 11  Importante empresa de telecomunicaciones solic...      Hace 7 días
# 12  Se requiere Desarrollador/a con experiencia mí...      Hace 7 días
# 13  Programador/a Senior conocimientos en Laravel,...  21 de noviembre
# 14  Se necesita programador con experiencia desarr...   Más de 30 días
# 15  ¡Si eres un desarrollador Full Stack que le gu...     Hace 3 horas
# 16  Importante empresa del sector tecnológico, con...    Hace 19 horas
# 17  Se solicita ingeniero o estudiante de últimos ...    Hace 20 horas
# 18  Browser Travel Solutions S.A.S se encuentra en...             Ayer
# 19  Nos encontramos en la búsqueda de ANALISTA NAC...             Ayer
